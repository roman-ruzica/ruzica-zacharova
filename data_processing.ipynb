# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AAPL = pd.read_csv("C:/Users/beaza/OneDrive/Počítač/UNI/3. semester/JEM207 Data Processing in Python/HW_collaboration/ruzica-zacharova/AAPL.csv", index_col = 'Date')
TSLA = pd.read_csv("C:/Users/beaza/OneDrive/Počítač/UNI/3. semester/JEM207 Data Processing in Python/HW_collaboration/ruzica-zacharova/TSLA.csv", index_col = 'Date')
GSPC = pd.read_csv("C:/Users/beaza/OneDrive/Počítač/UNI/3. semester/JEM207 Data Processing in Python/HW_collaboration/ruzica-zacharova/^GSPC.csv", index_col = 'Date')

# %%
AAPL.head
# Out:
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-10-14   58.724998   59.532501   58.667500   58.967499   58.388180
# 2019-10-15   59.097500   59.412498   58.720001   58.830002   58.252033
# 2019-10-16   58.342499   58.810001   58.299999   58.592499   58.016861
# 2019-10-17   58.772499   59.037498   58.380001   58.820000   58.242130
# 2019-10-18   58.647499   59.395000   58.572498   59.102501   58.521858
# ...                ...         ...         ...         ...         ...
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  115.080002
# 2020-10-08  116.250000  116.400002  114.589996  114.970001  114.970001
# 2020-10-09  115.279999  117.000000  114.919998  116.970001  116.970001
# 2020-10-12  120.059998  125.180000  119.279999  124.400002  124.400002
# 2020-10-13  125.269997  125.389999  119.650002  121.099998  121.099998
#
#                Volume
# Date
# 2019-10-14   96427600
# 2019-10-15   87360000
# ...

# %%
AAPL_adjclose = AAPL['Adj Close'].values
TSLA_adjclose = TSLA['Adj Close'].values
GSPC_adjclose = GSPC['Adj Close'].values

# %%
plt.plot(AAPL_adjclose)
plt.show()

# %%
plt.plot(TSLA_adjclose)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(GSPC_adjclose)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
